# %%
import pandas as pd
import pickle

# %%
x = 'outputs/preprocessed/X_dl_test.pkl'
y = 'outputs/preprocessed/y_test.pkl'

# %%
with open(x , 'rb') as f:
    x_data = pickle.load(f)

with open(y , 'rb') as f:
    y_data = pickle.load(f)

# %%
df = pd.DataFrame(x_data)

# %%
df['label'] = y_data

# %%
output_filename = 'combined_test_data.csv'
df.to_csv(output_filename, index=False)
